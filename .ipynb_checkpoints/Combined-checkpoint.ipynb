# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
import requests as req
import pandas as pd
import numpy as np
import time
import json
import plotly.plotly as py
import plotly
plotly.tools.set_credentials_file(username='kevious', api_key='Lm7iIiyKZ9sgAnQv0WWo')

# %%
#def comp_res():
# Zomato key
Key = '3da20c1582ac19fc8f4804414f67fc2e'

# prompt user for input city, generate url for response, get city ID to use in loop
city_lookup = input('Enter a city to query:')
url = "https://developers.zomato.com/api/v2.1/cities?&q=%s&results=100" % (city_lookup)
response = req.get(url, headers={"user-key" : Key}).json()
city_id = response['location_suggestions'][0]['id']
city_name = response['location_suggestions'][0]['name']

# build empty lists to hold restaurant info
names2 = []
lngs2 = []
lats2 = []
addresses2 = []
ratings2 = []
counts2 = []
cities = []
#cuisine_types = []

# start loop to request restaurant info
start = 0
for x in range(5):
    url = 'https://developers.zomato.com/api/v2.1/search?entity_id=%s&entity_type=city&sort=rating&order=desc&start=%s&count=500' % (city_id, start)
    response = req.get(url, headers={'user-key':Key}).json()
    for x in range(len(response['restaurants'])):
        names2.append(response['restaurants'][x]['restaurant']['name'])
        ratings2.append(response['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'])
        counts2.append(response['restaurants'][x]['restaurant']['user_rating']['votes'])
        addresses2.append(response['restaurants'][x]['restaurant']['location']['address'])
        lngs2.append(response['restaurants'][x]['restaurant']['location']['longitude'])
        lats2.append(response['restaurants'][x]['restaurant']['location']['latitude'])
        #cuisine_types.append(response['restaurants'][x]['restaurant']['cuisines'])
        cities.append(city_name)
    start = start + 20

# convert lists to dataframe, export
df2 = pd.DataFrame(columns={})      
df2['Name'] = names2
df2['Zomato Rating'] = ratings2
df2['Review Count'] = counts2
df2['Address'] = addresses2
df2['Longitude'] = lngs2
df2['Latitude'] = lats2
#df2['Cuisine Type'] = cuisine_types
df2['City Name'] = cities

# query Zomato results in Google API
google_ratings = []
input_city = city_lookup
location = geolocator.geocode(input_city)
latitude = location.latitude
longitude = location.longitude
target_city = {"lat": latitude, "lng": longitude}
radius = 8000
gkey = "AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY"
for x in range(len(df2)):
    keyword = df2['Name'][x]
    keyword = keyword.replace(" ", "+")
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&location=%s,%s&radius=%s&keyword=%s" % (gkey, target_city["lat"],
                                                                                                            target_city["lng"], 
                                                                                                            radius, keyword)
    response = req.get(url).json()
    try:
        google_ratings.append(response['results'][0]['rating'])
    except:
        google_ratings.append('N/A')

# combine data 
df2['Google Rating'] = google_ratings
df2 = df2.replace('N/A', np.NaN)
for index, row in df2.iterrows():
    zomato = df2['Zomato Rating'].astype(float)
    google = df2['Google Rating'].astype(float)
    df2['Composite Rating']= (zomato + google)/2

comp_drop_na = df2['Composite Rating'].fillna(df2['Zomato Rating'])
df2['Composite Rating'] = comp_drop_na
df2['Composite Rating'] = df2['Composite Rating'].astype(float)
df2.sort_values('Composite Rating', ascending=False)
df2.to_csv('comp_ratings.csv')

# %%
#comp_res()

# %%
df2.head()

# %%
# BEGIN YELP STUFF HERE

# %%
def request(host, path, api_key, url_params=None):
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }
    print(u'Querying {0} ...'.format(url))
    response = req.request('GET', url, headers=headers, params=url_params)
    return response.json()

# %%
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except:
    pass

# %%
API_KEY= 'WL_QeLUAQmRVoUHVkwxMEIc79D_Ue8TtH46lG4ZmJ0lazdecXZmca-93fDth3GmVKCtRXlURbIi-8YhnvofscAjTnIlCo_juQfccWDECUhrqZSXdVkaEwdjVtwqnWnYx' 

# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.
SEARCH_LIMIT = 50
OFFSET = 0

# %%
def search(api_key, term, location):
    OFFSET = 0
    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'sort_by': 'rating',
        'limit':SEARCH_LIMIT,
        'offset': OFFSET,
    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)

# %%
# yelp_ratings = []
# for name in names2:
#     term = name
#     location = 'Austin'
#     response = search(API_KEY, term, location)
#     yelp_ratings.append(response['businesses'][0]['rating'])

# %%
df2['Yelp Rating'] = yelp_ratings
df2.head()

# %%
#def comp_res():
# Zomato key
Key = '3da20c1582ac19fc8f4804414f67fc2e'

# prompt user for input city, generate url for response, get city ID to use in loop
city_lookup = input('Enter a city to query:')
url = "https://developers.zomato.com/api/v2.1/cities?&q=%s&results=100" % (city_lookup)
response = req.get(url, headers={"user-key" : Key}).json()
city_id = response['location_suggestions'][0]['id']
city_name = response['location_suggestions'][0]['name']

# build empty lists to hold restaurant info
names2 = []
lngs2 = []
lats2 = []
addresses2 = []
ratings2 = []
counts2 = []
cities = []
#cuisine_types = []

# start loop to request restaurant info
start = 0
for x in range(5):
    url = 'https://developers.zomato.com/api/v2.1/search?entity_id=%s&entity_type=city&sort=rating&order=desc&start=%s&count=500' % (city_id, start)
    response = req.get(url, headers={'user-key':Key}).json()
    for x in range(len(response['restaurants'])):
        names2.append(response['restaurants'][x]['restaurant']['name'])
        ratings2.append(response['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'])
        counts2.append(response['restaurants'][x]['restaurant']['user_rating']['votes'])
        addresses2.append(response['restaurants'][x]['restaurant']['location']['address'])
        lngs2.append(response['restaurants'][x]['restaurant']['location']['longitude'])
        lats2.append(response['restaurants'][x]['restaurant']['location']['latitude'])
        #cuisine_types.append(response['restaurants'][x]['restaurant']['cuisines'])
        cities.append(city_name)
    start = start + 20

# convert lists to dataframe, export
df2 = pd.DataFrame(columns={})      
df2['Name'] = names2
df2['Zomato Rating'] = ratings2
df2['Review Count'] = counts2
df2['Address'] = addresses2
df2['Longitude'] = lngs2
df2['Latitude'] = lats2
#df2['Cuisine Type'] = cuisine_types
df2['City Name'] = cities

# query Zomato results in Google API
google_ratings = []
input_city = city_lookup
location = geolocator.geocode(input_city)
latitude = location.latitude
longitude = location.longitude
target_city = {"lat": latitude, "lng": longitude}
radius = 8000
gkey = "AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY"
for x in range(len(df2)):
    keyword = df2['Name'][x]
    keyword = keyword.replace(" ", "+")
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&location=%s,%s&radius=%s&keyword=%s" % (gkey, target_city["lat"],
                                                                                                            target_city["lng"], 
                                                                                                            radius, keyword)
    response = req.get(url).json()
    try:
        google_ratings.append(response['results'][0]['rating'])
    except:
        google_ratings.append('N/A')


yelp_ratings = []
for name in names2:
    term = name
    location = 'Austin'
    response = search(API_KEY, term, location)
    yelp_ratings.append(response['businesses'][0]['rating'])        

# combine data 
df2['Google Rating'] = google_ratings
df2['Yelp Rating'] = yelp_ratings
df2 = df2.replace('N/A', np.NaN)
for index, row in df2.iterrows():
    zomato = df2['Zomato Rating'].astype(float)
    google = df2['Google Rating'].astype(float)
    yelp = df2['Yelp Rating'].astype(float)
    df2['Composite Rating']= (zomato + google + yelp)/3

comp_drop_na = df2['Composite Rating'].fillna((df2['Zomato Rating'].astype(float) + df2['Yelp Rating'].astype(float))/2)
df2['Composite Rating'] = comp_drop_na
df2['Composite Rating'] = df2['Composite Rating'].astype(float)
df2.sort_values('Composite Rating', ascending=False)
df2.to_csv('comp_ratings.csv')

# %%
df2.head(50)
# Out:
#                                 Name Zomato Rating Review Count  \
# 0                   Home Slice Pizza           4.9         2570
# 1               Jack Allen's Kitchen           4.8         1040
# 2        Moonshine Patio Bar & Grill           4.7         2022
# 3                Hopdoddy Burger Bar           4.7         1461
# 4                  Franklin Barbecue           4.6         1118
# 5                        Gourdough's           4.6          879
# 6              Titaya's Thai Cuisine           4.6          755
# 7                     Torchy's Tacos           4.5          900
# 8                               Uchi           4.5         1654
# 9                      Magnolia Cafe           4.5         1374
# 10               South Congress Café           4.5         1180
# 11  Rudy's Country Store and Bar-B-Q           4.5         1348
# 12                  Hut's Hamburgers           4.4         1870
# 13                   Enoteca Vespaio           4.4         1285
# 14          Mandola's Italian Market           4.4         1153
# 15                     Eastside Cafe           4.4          978
# 16                            Chuy's           4.4          949
# 17                  Amy's Ice Creams           4.4          671
# 18                Noble Sandwich Co.           4.4          502
# 19                   Evangeline Cafe           4.4          695
# 20            Little Deli & Pizzeria           4.4          398
# 21                          Hula Hut           4.3         1606
# 22                  Fonda San Miguel           4.3         1211
# 23                       Shady Grove           4.3         1100
# 24             Hyde Park Bar & Grill           4.3         1107
# 25                Blue Dahlia Bistro           4.3          615
# 26                            Chuy's           4.3          854
# 27                        P. Terry's           4.3          746
# 28                    Torchy's Tacos           4.3          566
# 29         The Old Pecan Street Cafe           4.3          701
# 30              Tarka Indian Kitchen           4.3          467
# 31                     Jardin Corona           4.3          680
# 32                          Tacodeli           4.3          414
# 33                           Phara's           4.3          324
# 34                          Clay Pit           4.2         1426
# 35           Eddie V's Prime Seafood           4.2          655
# 36                  Kerbey Lane Cafe           4.2          914
# 37                           Trudy's           4.2         1219
# 38                     Magnolia Cafe           4.2          776
# 39                Whole Foods Market           4.2          649
# 40                        Bartlett's           4.2          883
# 41            Mother's Cafe & Garden           4.2          605
# 42  Rudy's Country Store and Bar-B-Q           4.2          602
# 43               Maria's Taco Xpress           4.2          411
# 44          Mozart's Coffee Roasters           4.2          370
# 45                        Cafe Crépe           4.2          369
# 47  30.4000527778  Austin, TX            NaN          4.5          4.350000
# 48  30.2584411000  Austin, TX            4.6          4.0          4.266667
# 49  30.3708583333  Austin, TX            4.9          4.5          4.533333

# %%
for index, row in df2.iterrows():
    zomato = df2['Zomato Rating'].astype(float)
    google = df2['Google Rating'].astype(float)
    yelp = df2['Yelp Rating'].astype(float)
    df2['Composite Rating']= (zomato + google + yelp)/3

comp_drop_na = df2['Composite Rating'].fillna((df2['Zomato Rating'].astype(float) + df2['Yelp Rating'].astype(float))/2)
df2['Composite Rating'] = comp_drop_na
df2['Composite Rating'] = df2['Composite Rating'].astype(float)
df2.sort_values('Composite Rating', ascending=False)
df2.to_csv('comp_ratings.csv')

# %%
df2.sort_values('Composite Rating', ascending=False)
# Out:
#                                          Name Zomato Rating Review Count  \
# 0                            Home Slice Pizza           4.9         2570
# 7                              Torchy's Tacos           4.5          900
# 4                           Franklin Barbecue           4.6         1118
# 5                                 Gourdough's           4.6          879
# 2                 Moonshine Patio Bar & Grill           4.7         2022
# 20                     Little Deli & Pizzeria           4.4          398
# 28                             Torchy's Tacos           4.3          566
# 14                   Mandola's Italian Market           4.4         1153
# 49                             Torchy's Tacos           4.2          335
# 8                                        Uchi           4.5         1654
# 54                    Texas Honey Ham Company           4.2          313
# 11           Rudy's Country Store and Bar-B-Q           4.5         1348
# 18                         Noble Sandwich Co.           4.4          502
# 1                        Jack Allen's Kitchen           4.8         1040
# 51                          Taste of Ethiopia           4.2          318
# 35                    Eddie V's Prime Seafood           4.2          655
# 57                                     Uchiko           4.1          526
# 3                         Hopdoddy Burger Bar           4.7         1461
# 78                        Cabo Bob's Burritos           4.1          340
# 42           Rudy's Country Store and Bar-B-Q           4.2          602
# 62                         Bouldin Creek Cafe           4.1          393
# 79           Rudy's Country Store and Bar-B-Q           4.1          310
# 6                       Titaya's Thai Cuisine           4.6          755
# 52                               Midori Sushi           4.2          401
# 47                                  Cafe Java           4.2          441
# 99                                La Barbecue           4.0          269
# 17                           Amy's Ice Creams           4.4          671
# 25                         Blue Dahlia Bistro           4.3          615
# 82              Yanagi Restaurant & Sushi Bar           4.1          268
# 81                            Opie's Barbecue           4.1          223
# ..                                        ...           ...          ...
# 40                                 Bartlett's           4.2          883
# 90                                      Frank           4.0          500
# 85                 Lamberts Downtown Barbecue           4.0          805
# 75                                  Asia Cafe           4.1          258
# 12                           Hut's Hamburgers           4.4         1870
# 27                                 P. Terry's           4.3          746
# 24                      Hyde Park Bar & Grill           4.3         1107
# 29                  The Old Pecan Street Cafe           4.3          701
# 38                              Magnolia Cafe           4.2          776
# 73                    Sap's Fine Thai Cuisine           4.1          490
# 43                        Maria's Taco Xpress           4.2          411
# 37                                    Trudy's           4.2         1219
# 21                                   Hula Hut           4.3         1606
# 66                     Quality Seafood Market           4.1          420
# 23                                Shady Grove           4.3         1100
# 95                            Max's Wine Dive           4.0          393
# 68                       Piranha Killer Sushi           4.1          407
# 98                  G'Raj Mahal Cafe & Lounge           4.0          327
# 91                           Hoover's Cooking           4.0          555
# 93                              Curra's Grill           4.0          579
# 97                                    Taverna           4.0          458
# 88                           Matt's El Rancho           4.0          775
# 84                               Java Noodles           4.1          298
# 85  30.2652694444  Austin, TX            4.2          4.0          4.066667
# 75  30.4325694444  Austin, TX            NaN          4.0          4.050000
# 12  30.2703694444  Austin, TX            4.2          3.5          4.033333
# 27  30.2614638889  Austin, TX            4.3          3.5          4.033333
# 24  30.3042080000  Austin, TX            4.2          3.5          4.000000
# 29  30.2666250000  Austin, TX            4.2          3.5          4.000000
# 38  30.2778861111  Austin, TX            4.3          3.5          4.000000
# 73  30.2313944444  Austin, TX            4.4          3.5          4.000000
# 43  30.2459777778  Austin, TX            4.2          3.5          3.966667
# 37  30.2957300000  Austin, TX            4.2          3.5          3.966667
# 21  30.2948083333  Austin, TX            4.1          3.5          3.966667
# 66  30.3183277778  Austin, TX            4.3          3.5          3.966667
# 23  30.2626361111  Austin, TX            4.1          3.5          3.966667
# 95  30.2644277778  Austin, TX            4.2          3.5          3.900000
# 68  30.2641472222  Austin, TX            4.1          3.5          3.900000
# 98  30.2584750000  Austin, TX            4.2          3.5          3.900000
# 91  30.2842472222  Austin, TX            4.2          3.5          3.900000
# 93  30.2368972222  Austin, TX            4.2          3.5          3.900000
# 97  30.2651055556  Austin, TX            4.1          3.5          3.866667
# 88  30.2454861111  Austin, TX            4.1          3.5          3.866667
# 84  30.2293990000  Austin, TX            3.9          3.5          3.833333
# 87  30.3895666667  Austin, TX            4.0          3.5          3.833333
# 96  30.2724566000  Austin, TX            4.0          3.5          3.833333
# 83  30.2010833333  Austin, TX            NaN          3.5          3.800000
# 80  30.4720694444  Austin, TX            NaN          3.5          3.800000
# 76  30.2357555556  Austin, TX            NaN          3.5          3.800000
# 72  30.3594111111  Austin, TX            NaN          3.5          3.800000
# 89  30.3911850000  Austin, TX            NaN          3.5          3.750000
#
# [100 rows x 10 columns]

# %%
# # plotly

# scl = [ [0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
#     [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"] ]

# data = [ dict(
#         type = 'scattergeo',
#         locationmode = 'USA-states',
#         lon = df2['Longitude'],
#         lat = df2['Latitude'],
#         text = df2['Name'],
#         mode = 'markers',
#         marker = dict(
#             size = 8,
#             opacity = 0.8,
#             reversescale = True,
#             autocolorscale = False,
#             symbol = 'square',
#             line = dict(
#                 width=1,
#                 color='rgba(102, 102, 102)'
#             ),
#             colorscale = scl,
#             cmin = 0,
#             color = df2['Composite Rating'],
#             cmax = df2['Composite Rating'].max(),
#             colorbar=dict(
#                 title="Composite Rating"
#             )
#         ))]

# layout = dict(
#         title = 'Highest Rated Austin Restaurants',
#         colorbar = True,
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),
#             showland = True,
#             landcolor = "rgb(250, 250, 250)",
#             subunitcolor = "rgb(217, 217, 217)",
#             countrycolor = "rgb(217, 217, 217)",
#             countrywidth = 0.5,
#             subunitwidth = 0.5
#         ),
#     )

# # hover_info = dict(
# #             geo=dict(
# #             df2['Name'],
# #             df2['Address'],
# #             df2['Composite Rating'])
# # )


# fig = dict( data=data, layout=layout)
# py.iplot(fig, validate=False, filename='hover-chart-basic')
