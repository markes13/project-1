# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
import requests as req
import pandas as pd
import numpy as np
import tweepy
import time
import json
import plotly.plotly as py
import plotly
from plotly.graph_objs import *
import config as c

# %%
def request(host, path, api_key, url_params=None):
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }
    print(u'Querying {0} ...'.format(url))
    response = req.request('GET', url, headers=headers, params=url_params)
    return response.json()

# %%
def search(api_key, term, location):
    OFFSET = 0
    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'sort_by': 'rating',
        'limit':SEARCH_LIMIT,
        'offset': OFFSET,
    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)

# %%
# yelp info
API_KEY= c.yKey
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.
SEARCH_LIMIT = 50
OFFSET = 0

# %%
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except:
    pass

# %%
# tweet credentials

# Twitter API Keys
consumer_key = c.consumer_key
consumer_secret = c.consumer_secret
access_token = c.access_token
access_token_secret = c.access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# 1. BUILD DATA FRAME #################################################################################################
# Zomato key
zKey = c.zKey

# prompt user for input city, generate url for response, get city ID to use in loop
city_lookup = input('Enter a city to query:')
url = "https://developers.zomato.com/api/v2.1/cities?&q=%s&results=100" % (city_lookup)
response = req.get(url, headers={"user-key" : zKey}).json()
city_id = response['location_suggestions'][0]['id']
city_name = response['location_suggestions'][0]['name']

# build empty lists to hold restaurant info
names2 = []
lngs2 = []
lats2 = []
addresses2 = []
ratings2 = []
counts2 = []
cities = []
#cuisine_types = []

# start loop to request restaurant info
start = 0
for x in range(5):
    url = 'https://developers.zomato.com/api/v2.1/search?entity_id=%s&entity_type=city&sort=rating&order=desc&start=%s&count=500' % (city_id, start)
    response = req.get(url, headers={'user-key':zKey}).json()
    for x in range(len(response['restaurants'])):
        names2.append(response['restaurants'][x]['restaurant']['name'])
        ratings2.append(response['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'])
        counts2.append(response['restaurants'][x]['restaurant']['user_rating']['votes'])
        addresses2.append(response['restaurants'][x]['restaurant']['location']['address'])
        lngs2.append(response['restaurants'][x]['restaurant']['location']['longitude'])
        lats2.append(response['restaurants'][x]['restaurant']['location']['latitude'])
        #cuisine_types.append(response['restaurants'][x]['restaurant']['cuisines'])
        cities.append(city_name)
    start = start + 20

# convert lists to dataframe, export
df2 = pd.DataFrame(columns={})      
df2['Name'] = names2
df2['Zomato Rating'] = ratings2
df2['Zomato Review Count'] = counts2
df2['Address'] = addresses2
df2['Longitude'] = lngs2
df2['Latitude'] = lats2
#df2['Cuisine Type'] = cuisine_types
df2['City Name'] = cities

# query Zomato results in Google API (get Google ratings for each restaurant)
google_ratings = []
input_city = city_lookup
location = geolocator.geocode(input_city)
latitude = location.latitude
longitude = location.longitude
target_city = {"lat": latitude, "lng": longitude}
radius = 8000
gkey = c.gKey
for x in range(len(df2)):
    keyword = df2['Name'][x]
    keyword = keyword.replace(" ", "+")
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&location=%s,%s&radius=%s&keyword=%s" % (gkey, target_city["lat"],
                                                                                                            target_city["lng"], 
                                                                                                            radius, keyword)
    response = req.get(url).json()
    try:
        google_ratings.append(response['results'][0]['rating'])
    except:
        google_ratings.append('N/A')

# query Zomato results in Yelp API (get Yelp ratings for each restaurant)
yelp_ratings = []
yelp_reviews = []
for name in names2:
    term = name
    location = city_lookup
    response = search(API_KEY, term, location)
    yelp_ratings.append(response['businesses'][0]['rating'])
    yelp_reviews.append(response['businesses'][0]['review_count'])

# combine data 
df2['Google Rating'] = google_ratings
df2['Yelp Rating'] = yelp_ratings
df2['Yelp Review Count'] = yelp_reviews
df2 = df2.replace('N/A', np.NaN)
for index, row in df2.iterrows():
    zomato = df2['Zomato Rating'].astype(float)
    google = df2['Google Rating'].astype(float)
    yelp = df2['Yelp Rating'].astype(float)
    df2['Composite Rating'] = (zomato + google + yelp)/3
    df2['Total Review count'] = (df2['Zomato Review Count'].astype(int) + df2['Yelp Review Count'].astype(int))

comp_drop_na = df2['Composite Rating'].fillna((df2['Zomato Rating'].astype(float) + df2['Yelp Rating'].astype(float))/2)
df2['Composite Rating'] = comp_drop_na
df2['Composite Rating'] = df2['Composite Rating'].astype(float)
df2 = df2.sort_values('Composite Rating', ascending=False)
df2 = df2.reset_index(drop=True)

# export to CSV
df2.to_csv('comp_ratings.csv')

# 2. TWEET RESULTS ####################################################################################################
# tweet top 5 results
tweet_text = 'The top restaurants in %s this week are: 1. %s (%s), \
2. %s (%s), \
3. %s (%s), \
4. %s (%s), \
& 5. %s (%s)' % (
                 city_lookup,
                 df2['Name'][0], round(df2['Composite Rating'][0],2),
                 df2['Name'][1], round(df2['Composite Rating'][1],2),
                 df2['Name'][2], round(df2['Composite Rating'][2],2),
                 df2['Name'][3], round(df2['Composite Rating'][3],2),
                 df2['Name'][4], round(df2['Composite Rating'][4],2))


try:
    api.update_status(tweet_text)
except Exception as e:
    print(e)
    print("Attempted to tweet: {}".format(tweet_text))
# Out:
# Enter a city to query:Chicago
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...
# Querying https://api.yelp.com/v3/businesses/search ...

# %%
# 3. PLOTLY ###########################################################################################################
# build hover column
for index, row in df2.iterrows():
    df2['Hover'] = 'Name: ' + df2['Name'].astype(str) + '<br>Address: ' + df2['Address'].astype(str) \
    + '<br>Composite Rating: ' + round(df2['Composite Rating'], 2).astype(str) + '<br>Total Review Count: ' + df2['Total Review count'].astype(str)
    
# plotly map

# plotly credentials
mapbox_access_token = c.map_box_token
plotly.tools.set_credentials_file(username='kevious', api_key=c.pKey)

# map info
# get city lat and lon
location_geo = geolocator.geocode(city_lookup)
lat_set = location_geo.latitude
lon_set = location_geo.longitude

data = Data([
    Scattermapbox(
        lat=df2['Latitude'],
        lon=df2['Longitude'],
        mode='markers',
        marker=Marker(
            size=10
        ),
        text=df2['Hover'],
    )
])

layout = Layout(
    title='Top Restaurants in %s' % (city_lookup),
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=lat_set,
            lon=lon_set
        ),
        pitch=0,
        zoom=10,
    ),
)

fig = dict(data=data, layout=layout)
plotly.offline.plot(fig, filename='%s_restaurants.html') % (city_lookup)
# Out:
# 'file:///Users/marksquier/Desktop/project_1/Chicago_restaurants.html'

# %%
df2.head(100)
# Out:
#                                         Name Zomato Rating  \
# 0                             Maple Tree Inn           4.9
# 1                                 Smoque BBQ           4.8
# 2                               Paradise Pup           4.7
# 3        Walker Bros. Original Pancake House           4.7
# 4                                  Au Cheval           4.6
# 5                             Johnnie's Beef           4.6
# 6                      Original Rainbow Cone           4.6
# 7                              Sen Sushi Bar           4.6
# 8                       Top Notch Beefburger           4.6
# 9                                     Alinea           4.5
# 10   Joe's Seafood, Prime Steak & Stone Crab           4.4
# 11                             Naf Naf Grill           4.6
# 12                              Fogo de Chão           4.4
# 13                 Homer's Ice Cream Company           4.5
# 14                                 Lula Cafe           4.5
# 15                                  Pita Inn           4.5
# 16               Gene & Jude's Red Hot Stand           4.7
# 17                            The Purple Pig           4.9
# 18                               Bien Trucha           4.4
# 19                            Big & Little's           4.5
# 20                            Pequod's Pizza           4.9
# 21                             Kuma's Corner           4.8
# 22                                  Hog Wild           4.8
# 23                          Café Ba-Ba-Reeba           4.7
# 24                                      Xoco           4.8
# 25                  Gibsons Bar & Steakhouse           4.6
# 26                                     Piece           4.7
# 27                                      Yolk           4.7
# 28                          Molly's Cupcakes           4.5
# 29                           Longman & Eagle           4.5
# ..                                       ...           ...
# 70                    Joy's Noodles and Rice           4.4
# 71                             Glenn's Diner           4.4
# 72  Tsukasa Japanese Steak, Seafood, & Sushi           4.4
# 73                              Meson Sabika           4.4
# 74                             Spacca Napoli           4.4
# 75                             Athenian Room           4.4
# 76                                  M. Henry           4.4
# 77                        Mercat a la Planxa           4.4
# 78                                Portillo's           4.9
# 79                                Portillo's           4.9
# 80                                  Big Star           4.5
# 81                              Cafe Iberico           4.6
# 82                            Lou Mitchell's           4.4
# 83                            Grand Lux Cafe           4.4
# 84                                Yard House           4.4
# 85                                Portillo's           4.7
# 86                                Portillo's           4.6
# 87                                Portillo's           4.5
# 88                            Medici on 57th           4.5
# 89                                Portillo's           4.5
# 90                               Sarkis Cafe           4.5
# 91                                Portillo's           4.5
# 92                                Cafe Corea           4.5
# 93                                Portillo's           4.4
# 94                  Yu's Mandarin Restaurant           4.4
# 95                       Chi Tung Restaurant           4.4
# 96                             Buffalo Joe's           4.4
# 97                           San Soo Gab San           4.4
# 98                           Girl & the Goat           4.6
# 99                           Hamada of Japan           4.5
#
#    Zomato Review Count                                            Address  \
# 0                  376       13301 Olde Western Avenue, Blue Island 60406
# 1                 1561                          3800 N Pulaski Road 60641
# 2                  550               1724 S River Road, Des Plaines 60016
# 3                  528                 153 Green Bay Road, Wilmette 60091
# 4                  295               800 W Randolph Street, Chicago 60607
# 5                  474                 7500 W North Avenue, Elmwood 60707
# 6                  338               9233 S Western Avenue, Chicago 60643
# 7                  284             814 S. Oak Park Avenue, Oak Park 60304
# 8                  299                  2116 W 95th Street, Chicago 60643
# 9                  890                        1723 N Halsted Street 60614
# 10                 875                            60 E Grand Avenue 60611
# 11                 378                 1739 Freedom Drive, Unit 109 60563
# 12                1463                      661 N Lasalle Boulevard 60654
# 13                 281                1237 Green Bay Road, Wilmette 60091
# 14                 897                     2537 N. Kedzie Boulevard 60647
# 15                 479                 4710 Dempster Street, Skokie 60076
# 16                 819                 2720 River Road, River Grove 60171
# 17                1759               500 N Michigan Avenue, Chicago 60611
# 18                 536                          410 W. State Street 60134
# 19                 300                860 N Orleans Street, Chicago 60610
# 20                 937                       2207 N Clybourn Avenue 60614
# 21                1561               2900 W Belmont Avenue, Chicago 60618
# 22                 410               14933 Pulaski Road, Midlothian 60445
# 23                1736                        2024 N Halsted Street 60614
# 24                1191                  449 N Clark Street, Chicago 60654
# 25                1024                           1028 N Rush Street 60611
# 26                1189                          1927 W North Avenue 60622
# 27                1345              1120 S Michigan Avenue, Chicago 60605
# 28                 465                          2536 N Clark Street 60614
# 29                 458                2657 N Kedzie Avenue, Chicago 60647
# ..                 ...                                                ...
# 70                 606                   3257 North Broadway Street 60657
# 71                 490                       1820 W Montrose Avenue 60613
# 72                 587         501 N Milwaukee Avenue, Vernon Hills 60061
# 73                 596                           1025 Aurora Avenue 60540
# 74                 551             1769 W Sunnyside Avenue, Chicago 60640
# 75                 465                         807 W Webster Avenue 60614
# 76                 673                 5707 N Clark Street, Chicago 60660
# 77                 591  Renaissance Blackstone Chicago Hotel, 638 S Mi...
# 78                1793                         100 W Ontario Street 60610
# 79                 926                   1992 West Jefferson Avenue 60540
# 80                 701                 1531 N Damen Avenue, Chicago 60622
# 81                1114                         739 N La Salle Drive 60610
# 82                 333             565 W Jackson Boulevard, Chicago 60661
# 83                2403                        600 N Michigan Avenue 60611
# 84                 345  The Glen Tower Center, 1880 Tower Drive,Glenvi...
# 85                 705                              611 E Golf Road 60173
# 86                 347           221 E. Townline Road, Vernon Hills 60061
# 87                 345            950 East Ogden Avenue, Naperville 60563
# 88                 572                           1327 E 57th Street 60637
# 89                 330  Ridge Plaza, 806 W. Dundee Road, Arlington Hei...
# 90                 942                        2632 Gross Point Road 60201
# 91                 284                  531 N Randall Road, Batavia 60510
# 92                 245                  1603 E 55th Street, Chicago 60615
# 93                 326         1500 Butterfield Road, Downers Grove 60515
# 94                 492                              200 E Golf Road 60173
# 95                 388        9560 S. Kedzie Avenue, Evergreen Park 60805
# 96                 407                             812 Clark Street 60201
# 97                 392                       5247 N. Western Avenue 60625
# 98                1334               809 W Randolph Street, Chicago 60607
# 99                 363         18310 North Creek Drive, Tinley Park 60477
#
#          Longitude       Latitude    City Name  Google Rating  Yelp Rating  \
# 0   -87.6812138889  41.6511500000  Chicago, IL            NaN          4.5
# 1   -87.7276840000  41.9503040000  Chicago, IL            NaN          4.5
# 2   -87.8762444444  42.0221333333  Chicago, IL            NaN          4.5
# 3   -87.7043222222  42.0707388889  Chicago, IL            NaN          4.5
# 4   -87.6475833333  41.8845055556  Chicago, IL            4.6          4.5
# 5   -87.8132472222  41.9089361111  Chicago, IL            NaN          4.5
# 6   -87.6820361111  41.7254361111  Chicago, IL            NaN          4.5
# 7   -87.7940444444  41.8736000000  Chicago, IL            NaN          4.5
# 8   -87.6754916667  41.7211694444  Chicago, IL            NaN          4.5
# 9   -87.6483077000  41.9135455000  Chicago, IL            4.6          4.5
# 10  -87.6261590000  41.8918370000  Chicago, IL            4.6          4.5
# 11  -88.1273416667  41.8022027778  Chicago, IL            4.4          4.5
# 12  -87.6325305556  41.8943722222  Chicago, IL            4.6          4.5
# 13  -87.7152000000  42.0837000000  Chicago, IL            NaN          4.5
# 14  -87.7071150000  41.9273470000  Chicago, IL            4.5          4.5
# 15  -87.7451570000  42.0407870000  Chicago, IL            NaN          4.5
# 16  -87.8466111111  41.9299972222  Chicago, IL            4.2          4.5
# 17  -87.6248472222  41.8911277778  Chicago, IL            4.5          4.0
# 18  -88.3099130000  41.8878490000  Chicago, IL            NaN          4.5
# 19  -87.6373972222  41.8984722222  Chicago, IL            4.8          4.0
# 20  -87.6646583333  41.9217500000  Chicago, IL            4.4          4.0
# 21  -87.7004680000  41.9395050000  Chicago, IL            4.5          4.0
# 22  -87.7174000000  41.6210000000  Chicago, IL            NaN          4.0
# 23  -87.6488194444  41.9188083333  Chicago, IL            4.5          4.0
# 24  -87.6310722222  41.8907916667  Chicago, IL            4.4          4.0
# 25  -87.6281420000  41.9016920000  Chicago, IL            4.6          4.0
# 26  -87.6761270000  41.9103660000  Chicago, IL            4.4          4.0
# 27  -87.6244500000  41.8688000000  Chicago, IL            4.4          4.0
# 28  -87.6423416667  41.9287722222  Chicago, IL            4.6          4.0
# 29  -87.7072444444  41.9301861111  Chicago, IL            4.6          4.0
# ..             ...            ...          ...            ...          ...
# 70  -87.6445000000  41.9418055556  Chicago, IL            4.2          4.0
# 71  -87.6754444444  41.9615833333  Chicago, IL            NaN          4.0
# 72  -87.9440000000  42.2370000000  Chicago, IL            NaN          4.0
# 73  -88.1624000000  41.7682000000  Chicago, IL            NaN          4.0
# 74  -87.6735000000  41.9633305556  Chicago, IL            NaN          4.0
# 75  -87.6490861111  41.9217611111  Chicago, IL            4.2          4.0
# 76  -87.6692722222  41.9855805556  Chicago, IL            NaN          4.0
# 77  -87.6244500000  41.8733277778  Chicago, IL            4.2          4.0
# 78  -87.6314166667  41.8935000000  Chicago, IL            4.5          3.0
# 79  -88.2054000000  41.7701000000  Chicago, IL            4.5          3.0
# 80  -87.6772527778  41.9092416667  Chicago, IL            4.4          3.5
# 81  -87.6329111111  41.8959916667  Chicago, IL            4.2          3.5
# 82  -87.6421750000  41.8781694444  Chicago, IL            4.4          3.5
# 83  -87.6251138889  41.8935805556  Chicago, IL            4.3          3.5
# 84  -87.8243638889  42.0891222222  Chicago, IL            4.3          3.5
# 85  -88.0637583333  42.0494694444  Chicago, IL            4.5          3.0
# 86  -87.9592000000  42.2404000000  Chicago, IL            4.5          3.0
# 87  -88.1320111111  41.7893138889  Chicago, IL            4.5          3.0
# 88  -87.5936194444  41.7914055556  Chicago, IL            NaN          3.5
# 89  -87.9921111111  42.1393861111  Chicago, IL            4.5          3.0
# 90  -87.7271583333  42.0656888889  Chicago, IL            NaN          3.5
# 91  -88.3414100000  41.8608030000  Chicago, IL            4.5          3.0
# 92  -87.5864944444  41.7952083333  Chicago, IL            NaN          3.5
# 93  -88.0226527778  41.8344527778  Chicago, IL            4.5          3.0
# 94  -88.0742638889  42.0507000000  Chicago, IL            NaN          3.5
# 95  -87.7020000000  41.7197000000  Chicago, IL            NaN          3.5
# 96  -87.6826472222  42.0500722222  Chicago, IL            NaN          3.5
# 97  -87.6890140000  41.9770910000  Chicago, IL            NaN          3.5
# 98  -87.6478805556  41.8843027778  Chicago, IL            2.7          4.5
# 99  -87.7966777778  41.5579138889  Chicago, IL            NaN          3.0
#
#     Yelp Review Count  Composite Rating  Total Review count  \
# 0                 301          4.700000                 677
# 1                3690          4.650000                5251
# 2                 702          4.600000                1252
# 3                 580          4.600000                1108
# 4                4829          4.566667                5124
# 5                 961          4.550000                1435
# 6                 272          4.550000                 610
# 7                 403          4.550000                 687
# 8                4829          4.550000                5128
# 9                1758          4.533333                2648
# 10               1984          4.500000                2859
# 11                416          4.500000                 794
# 12               1408          4.500000                2871
# 13               6934          4.500000                7215
# 14               1697          4.500000                2594
# 15                350          4.500000                 829
# 16                291          4.466667                1110
# 17               5727          4.466667                7486
# 18                932          4.450000                1468
# 19               1102          4.433333                1402
# 20                785          4.433333                1722
# 21               4779          4.433333                6340
# 22                516          4.400000                 926
# 23               3256          4.400000                4992
# 24               3298          4.400000                4489
# 25               1584          4.400000                2608
# 26               3216          4.366667                4405
# 27               1622          4.366667                2967
# 28               2552          4.366667                3017
# 29               2181          4.366667                2639
# ..                ...               ...                 ...
# 70                841          4.200000                1447
# 71               1090          4.200000                1580
# 72                296          4.200000                 883
# 73                812          4.200000                1408
# 74               1264          4.200000                1815
# 75                620          4.200000                1085
# 76               1556          4.200000                2229
# 77               1298          4.200000                1889
# 78                257          4.133333                2050
# 79                257          4.133333                1183
# 80               2907          4.133333                3608
# 81               1948          4.100000                3062
# 82                782          4.100000                1115
# 83               1833          4.066667                4236
# 84                229          4.066667                 574
# 85                257          4.066667                 962
# 86                257          4.033333                 604
# 87                257          4.000000                 602
# 88                700          4.000000                1272
# 89                257          4.000000                 587
# 90                324          4.000000                1266
# 91                257          4.000000                 541
# 92                112          4.000000                 357
# 93                257          3.966667                 583
# 94                775          3.950000                1267
# 95                693          3.950000                1081
# 96                 85          3.950000                 492
# 97               1155          3.950000                1547
# 98               6934          3.933333                8268
# 99                213          3.750000                 576
#
#                                                 Hover
# 0   Name: Maple Tree Inn<br>Address: 13301 Olde We...
# 1   Name: Smoque BBQ<br>Address: 3800 N Pulaski Ro...
# 2   Name: Paradise Pup<br>Address: 1724 S River Ro...
# 3   Name: Walker Bros. Original Pancake House<br>A...
# 4   Name: Au Cheval<br>Address: 800 W Randolph Str...
# 5   Name: Johnnie's Beef<br>Address: 7500 W North ...
# 6   Name: Original Rainbow Cone<br>Address: 9233 S...
# 7   Name: Sen Sushi Bar<br>Address: 814 S. Oak Par...
# 8   Name: Top Notch Beefburger<br>Address: 2116 W ...
# 9   Name: Alinea<br>Address: 1723 N Halsted Street...
# 10  Name: Joe's Seafood, Prime Steak & Stone Crab<...
# 11  Name: Naf Naf Grill<br>Address: 1739 Freedom D...
# 12  Name: Fogo de Chão<br>Address: 661 N Lasalle B...
# 13  Name: Homer's Ice Cream Company<br>Address: 12...
# 14  Name: Lula Cafe<br>Address: 2537 N. Kedzie Bou...
# 15  Name: Pita Inn<br>Address: 4710 Dempster Stree...
# 16  Name: Gene & Jude's Red Hot Stand<br>Address: ...
# 17  Name: The Purple Pig<br>Address: 500 N Michiga...
# 18  Name: Bien Trucha<br>Address: 410 W. State Str...
# 19  Name: Big & Little's<br>Address: 860 N Orleans...
# 20  Name: Pequod's Pizza<br>Address: 2207 N Clybou...
# 21  Name: Kuma's Corner<br>Address: 2900 W Belmont...
# 22  Name: Hog Wild<br>Address: 14933 Pulaski Road,...
# 23  Name: Café Ba-Ba-Reeba<br>Address: 2024 N Hals...
# 24  Name: Xoco<br>Address: 449 N Clark Street, Chi...
# 25  Name: Gibsons Bar & Steakhouse<br>Address: 102...
# 26  Name: Piece<br>Address: 1927 W North Avenue 60...
# 27  Name: Yolk<br>Address: 1120 S Michigan Avenue,...
# 28  Name: Molly's Cupcakes<br>Address: 2536 N Clar...
# 29  Name: Longman & Eagle<br>Address: 2657 N Kedzi...
# ..                                                ...
# 70  Name: Joy's Noodles and Rice<br>Address: 3257 ...
# 71  Name: Glenn's Diner<br>Address: 1820 W Montros...
# 72  Name: Tsukasa Japanese Steak, Seafood, & Sushi...
# 73  Name: Meson Sabika<br>Address: 1025 Aurora Ave...
# 74  Name: Spacca Napoli<br>Address: 1769 W Sunnysi...
# 75  Name: Athenian Room<br>Address: 807 W Webster ...
# 76  Name: M. Henry<br>Address: 5707 N Clark Street...
# 77  Name: Mercat a la Planxa<br>Address: Renaissan...
# 78  Name: Portillo's<br>Address: 100 W Ontario Str...
# 79  Name: Portillo's<br>Address: 1992 West Jeffers...
# 80  Name: Big Star<br>Address: 1531 N Damen Avenue...
# 81  Name: Cafe Iberico<br>Address: 739 N La Salle ...
# 82  Name: Lou Mitchell's<br>Address: 565 W Jackson...
# 83  Name: Grand Lux Cafe<br>Address: 600 N Michiga...
# 84  Name: Yard House<br>Address: The Glen Tower Ce...
# 85  Name: Portillo's<br>Address: 611 E Golf Road 6...
# 86  Name: Portillo's<br>Address: 221 E. Townline R...
# 87  Name: Portillo's<br>Address: 950 East Ogden Av...
# 88  Name: Medici on 57th<br>Address: 1327 E 57th S...
# 89  Name: Portillo's<br>Address: Ridge Plaza, 806 ...
# 90  Name: Sarkis Cafe<br>Address: 2632 Gross Point...
# 91  Name: Portillo's<br>Address: 531 N Randall Roa...
# 92  Name: Cafe Corea<br>Address: 1603 E 55th Stree...
# 93  Name: Portillo's<br>Address: 1500 Butterfield ...
# 94  Name: Yu's Mandarin Restaurant<br>Address: 200...
# 95  Name: Chi Tung Restaurant<br>Address: 9560 S. ...
# 96  Name: Buffalo Joe's<br>Address: 812 Clark Stre...
# 97  Name: San Soo Gab San<br>Address: 5247 N. West...
# 98  Name: Girl & the Goat<br>Address: 809 W Randol...
# 99  Name: Hamada of Japan<br>Address: 18310 North ...
#
# [100 rows x 13 columns]
