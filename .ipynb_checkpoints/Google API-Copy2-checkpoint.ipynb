# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
import requests as req
import pandas as pd
import json
import time

# %%
api_key = "AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY"

# %%
# lookup_city = input('Enter a city to query:')

# %%
# location = geolocator.geocode(lookup_city)
# lat = location.latitude
# lng = location.longitude

# %%
lookup_city = input('Enter a city to query:')
location = geolocator.geocode(lookup_city)
lat = location.latitude
lng = location.longitude
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=%s,%s&key=%s" % (lat, lng, api_key)
print(url)
response = req.get(url).json()
restaurants = []
ratings = []
locations = []
lats = []
lngs = []
for x in range(len(response['results'])):
        try:
            restaurants.append(response['results'][x]['name'])
            ratings.append(response['results'][x]['rating'])
            locations.append(response['results'][x]['vicinity'])
            lats.append(response['results'][x]['geometry']['location']['lat'])
            lngs.append(response['results'][x]['geometry']['location']['lng'])
        except:
            ratings.append('No rating available.')
            locations.append('No address available')
            lats.append('No latitude available')
            lngs.append('No longitude available')
next_page_token = response['next_page_token']
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=%s,%s&key=%s&pagetoken=%s" % (lat, lng, api_key, next_page_token)
print(url)
for x in range(len(response['results'])):
    try:
        restaurants.append(response['results'][x]['name'])
        ratings.append(response['results'][x]['rating'])
        locations.append(response['results'][x]['vicinity'])
        lats.append(response['results'][x]['geometry']['location']['lat'])
        lngs.append(response['results'][x]['geometry']['location']['lng'])
    except:
        ratings.append('No rating available.')
        locations.append('No address available')
        lats.append('No latitude available')
        lngs.append('No longitude available')
df = pd.DataFrame(columns={})

for x in range(4):
    lat = lat - 0.005
    lng = lng - 0.005
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=%s,%s&key=%s" % (lat, lng, api_key)
    print(url)
    response = req.get(url).json()
    restaurants = []
    ratings = []
    locations = []
    lats = []
    lngs = []
    for x in range(len(response['results'])):
        try:
            restaurants.append(response['results'][x]['name'])
            ratings.append(response['results'][x]['rating'])
            locations.append(response['results'][x]['vicinity'])
            lats.append(response['results'][x]['geometry']['location']['lat'])
            lngs.append(response['results'][x]['geometry']['location']['lng'])
        except:
            ratings.append('No rating available.')
            locations.append('No address available')
            lats.append('No latitude available')
            lngs.append('No longitude available')
    next_page_token = response['next_page_token']
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=%s,%s&key=%s&pagetoken=%s" % (lat, lng, api_key, next_page_token)
    print(url)
    for x in range(len(response['results'])):
        try:
            restaurants.append(response['results'][x]['name'])
            ratings.append(response['results'][x]['rating'])
            locations.append(response['results'][x]['vicinity'])
            lats.append(response['results'][x]['geometry']['location']['lat'])
            lngs.append(response['results'][x]['geometry']['location']['lng'])
        except:
            ratings.append('No rating available.')
            locations.append('No address available')
            lats.append('No latitude available')
            lngs.append('No longitude available')
            
df = pd.DataFrame(columns={})
df["Restaurant"] = restaurants
df["Ratings"] = ratings
df["Address"] = locations
df["Latitude"] = lats
df["Longitude"] = lngs
print(df)
# Out:
# Enter a city to query:Austin, TX
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.2711286,-97.7436995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.2711286,-97.7436995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAACGe98KCQ46o7KRNXiqHYhZVCtbRtUkwCfBDi8FPPOIQFyVWZNLgw8eNBA8fOVqCbr3BzDpcGz62jTHlUdp3nWFaSRCQAPDucfF-oEXbfmx-Efh3iCTx8pNN9iOPeiz28DnXba91MxgdxQUTfaxyqgd48bL0QoMTg5trXqHsopZdgJUMaM-QyJLLCleYnS6_7LC_EYnRVG2YreFLNAiNY3YRPIUDCEnH6rZdoOd4dsf2DwR5cpjD8DZMLZWpkXjUV7v3i9ZC7TwJopWQTy1JYIaf4CEjBVQEu0p4MpzPkh_c2nHuY0xyxsAIUG3cnpT6XvaCtKnlPDGjrWxN8U3yZtWSLiDhfuAETAS0IJXYUrDcGUXfdTUF7UcEaQLz8vYUzxIQBBP-HBBhf65YARghHwhRJhoUcLK5YkGnUgFaoqkOKlvmRQOeKTY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.266128600000002,-97.7486995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.266128600000002,-97.7486995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAHCu84p3SPsfTU-_t6vgVFTr692kV6GagI3g8C3YgHMYIWXtzfS8-0syPTY4NmLcK4cq6sDbkZPZBN2yapHo6pJT4qQ5G4Pchuj5IAHHYg8MnSCrZGCtDhBuy-jAwe4yAO3xWc1CItH04aRZXvivuHdiXP4op-PpezL9R8izgRgZzP9qd9QRE5gNwMTpuwVFSzczLtnPBLuDqFtN7_JO3cr2A6Ktj9Q638n5CX3mGMQDRtXWRsJ-XBKpDQb6iOwCr_DP5u1IxcqzQprYs5ja2TrQiF-q2gvDhejQXuca2ZnSSV1kI7fLcEfsoZmiyC68lTwkFjRNo9dY4qlyc0-2iRQRJhjocHvIMGreC_pFq_evCgR4ohXGlGyG48YsoA0SoBIQ7CRSo7bp4W2NXKe81sz3RRoUbYiyiAlLkOD2wV3ZVv2YELqpPDA
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.261128600000003,-97.7536995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.261128600000003,-97.7536995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAABkyGQWvMznK964YHMJl4oHK3JQUq4-2ZOdTBEhhTa4kNQ1nvXjIb_XYFUgnxMNFbeHtS1Yf69Tt9tnOSid8dxXDlIPwC8lU32k0xdop1kdqO1z2yM7CbE6VR84qOcTxJXHObTeVMs6zlCOnhzji4CWzxz7VCs2w1HYBapWQ92G-D4yB7VBYKx1SDKcvctr0pGOEGDPmnj1sIGVNW1mLt5gQb8TPuoPLl-w45GK79-rDZncYwEgWwYWFtwf9zQsnDNb2qHITyu3vNCkSDNIf8jaBDtDc0Z4RqhFbvxPfIVRdQ2i0QmdRSBGqpXNx7r2_3ZAfX82G65QmPXo0zqBxDGOTQXyfxOzB0JlvX6ylsR6cT4AnX-SiOLag9qMgl8vh1xIQQcvIVp_0YvnbCa1jdTcGkhoUtz0NS6bLl9_-oRmBLFVH57SWLNo
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.256128600000004,-97.75869949999999&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.256128600000004,-97.75869949999999&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAOYBOO6JEguBhei4U4c4S4gaKjYE375SaLktYLusemmBHFxgKjGo4B0Mx5bDvgq7WkZhln-P7-ZlIZEdBzPwkmwvm41Pyu7Puu-OkuaFVAIfNnW8cuBI-o5Bj1oJQ8OoNUMdMcsDnLK5YLoYRtDrcl-tqO4GBTc-K9bNCJmcHUb4esVbkfXjUlf804t21xayyOEHl1upTo2BKvEjSWz4b8Ys4YR1Ish9ME68lrITAZmwchYkkPoLIwAaryQqcPv4dAsnVsvFLP_5Y3lAjLBzYlzLB9GWDR4qyD0th76EFcZQPAO4fzxoWgKi4mUBY-K04UDIEK5tclpJXmBTosJvDQ8qyLtkNOVoSzNKziHc1VRcFBZAIIpJwdSVIZ28-fj4fRIQBASHecIk-Yuy2Io_yDEA3hoUxOJAjH545vt30scTDiDr95yPr6o
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.251128600000005,-97.76369949999999&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=100000&location=30.251128600000005,-97.76369949999999&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAOICvFbcBY3oqJYGKjls1GFBGXB7ePwMLFfEjSg_ZzJe8YQbQMLM5hyxU5qrelkKhKVHmNQeaHlJkRWofubNxFywCCMwUgyd0a6A6NXTSB6H9u9WhMmwetadFmX0iZhWFBk7BjldOYYZfZ5cHTJdk_6pjgU0lKkmrTB587CptxrQHSfDgm2_eo49jsEmDz8qVpR_s8aAVXYcCdPSdGRMDzvh29EMO0Pzhx04RiftiAsZKfK-L0CX8x-R1lXE-x-yumUUjZxqST0uh65xmdWiG_2vHYBGIF9YnyEfWP7RcWZs8TyNVfNmPBm3fxH7zhX6k8RXXa5ts_an7_sr55gR_0TbEeWCZezzsh8lgaQ5jdYoqkXncmJDfCuPeG1xHVi95RIQ7ofGnKX2NV7ptj9xYTfEWRoU_FmCOBlzGa-D2Xb7u3li6ypfrj4
#                                  Restaurant  Ratings  \
# 0              Holiday Inn Austin Town Lake      3.9
# 1      Sheraton Austin Hotel at the Capitol      4.0
# 2   Embassy Suites by Hilton Austin Central      3.9
# 3                    Lakeway Resort and Spa      4.1
# 4                                  Parkside      4.2
# 5                  Main Event Entertainment      4.0
# 6                              P.F. Chang's      4.0
# 7                    Cherrywood Coffeehouse      4.5
# 8                   Maggiano's Little Italy      4.2
# 9                      Tarka Indian Kitchen      4.3
# 10                           Torchy's Tacos      4.6
# 11                 Palazio Gentlemen's Club      3.5
# 12                                  Perla's      4.3
# 13                  Eddie V's Prime Seafood      4.6
# 14                    Alamo Drafthouse Ritz      4.6
# 15              Perry's Steakhouse & Grille      4.6
# 16                                   Subway      2.6
# 17          Olive Garden Italian Restaurant      4.2
# 18                        Franklin Barbecue      4.7
# 19                            Maudie's Cafe      4.0
# 20             Holiday Inn Austin Town Lake      3.9
# 21     Sheraton Austin Hotel at the Capitol      4.0
# 22  Embassy Suites by Hilton Austin Central      3.9
# 23                   Lakeway Resort and Spa      4.1
# 24                                 Parkside      4.2
# 25                 Main Event Entertainment      4.0
# 26                             P.F. Chang's      4.0
# 27                   Cherrywood Coffeehouse      4.5
# 28                  Maggiano's Little Italy      4.2
# 29                     Tarka Indian Kitchen      4.3
# 30                           Torchy's Tacos      4.6
# 31                 Palazio Gentlemen's Club      3.5
# 32                                  Perla's      4.3
# 33                  Eddie V's Prime Seafood      4.6
# 34                    Alamo Drafthouse Ritz      4.6
# 35              Perry's Steakhouse & Grille      4.6
# 36                                   Subway      2.6
# 37          Olive Garden Italian Restaurant      4.2
# 38                        Franklin Barbecue      4.7
# 39                            Maudie's Cafe      4.0
#
#                                               Address   Latitude  Longitude
# 0                              20 North Ih-35, Austin  30.253425 -97.737320
# 1                        701 East 11th Street, Austin  30.270406 -97.734231
# 2                            5901 North IH-35, Austin  30.319443 -97.705619
# 3                          101 Lakeway Drive, Lakeway  30.374544 -97.986899
# 4                         301 East 6th Street, Austin  30.267227 -97.740314
# 5                      13301 North US Hwy 183, Austin  30.445434 -97.784630
# 6                   201 San Jacinto Boulevard, Austin  30.263855 -97.741595
# 7                   1400 East 38th 1/2 Street, Austin  30.293533 -97.716013
# 8                10910 Domain Drive Suite 100, Austin  30.395168 -97.726991
# 9                       5207 Brodie Lane #120, Austin  30.230869 -97.817544
# 10                      1311 South 1st Street, Austin  30.250926 -97.754234
# 11               501 East Ben White Boulevard, Austin  30.218939 -97.758547
# 12                 1400 South Congress Avenue, Austin  30.249958 -97.750091
# 13                        301 East 5th Street, Austin  30.266255 -97.740658
# 14                        320 East 6th Street, Austin  30.267447 -97.739565
# 15                        114 West 7th Street, Austin  30.269412 -97.743528
# 16  9300 South Interstate 35 Frontage Road #7, Austin  30.163824 -97.790476
# 17                   100 Sundance Parkway, Round Rock  30.484356 -97.676246
# 18                       900 East 11th Street, Austin  30.270142 -97.731271
# 19                       2608 West 7th Street, Austin  30.282812 -97.775668
# 20                             20 North Ih-35, Austin  30.253425 -97.737320
# 21                       701 East 11th Street, Austin  30.270406 -97.734231
# 22                           5901 North IH-35, Austin  30.319443 -97.705619
# 23                         101 Lakeway Drive, Lakeway  30.374544 -97.986899
# 24                        301 East 6th Street, Austin  30.267227 -97.740314
# 25                     13301 North US Hwy 183, Austin  30.445434 -97.784630
# 26                  201 San Jacinto Boulevard, Austin  30.263855 -97.741595
# 27                  1400 East 38th 1/2 Street, Austin  30.293533 -97.716013
# 28               10910 Domain Drive Suite 100, Austin  30.395168 -97.726991
# 29                      5207 Brodie Lane #120, Austin  30.230869 -97.817544
# 30                      1311 South 1st Street, Austin  30.250926 -97.754234
# 31               501 East Ben White Boulevard, Austin  30.218939 -97.758547
# 32                 1400 South Congress Avenue, Austin  30.249958 -97.750091
# 33                        301 East 5th Street, Austin  30.266255 -97.740658
# 34                        320 East 6th Street, Austin  30.267447 -97.739565
# 35                        114 West 7th Street, Austin  30.269412 -97.743528
# 36  9300 South Interstate 35 Frontage Road #7, Austin  30.163824 -97.790476
# 37                   100 Sundance Parkway, Round Rock  30.484356 -97.676246
# 38                       900 East 11th Street, Austin  30.270142 -97.731271
# 39                       2608 West 7th Street, Austin  30.282812 -97.775668

# %%
# rankby importance w/ 60 results

# prompt user for input city
lookup_city = input('Enter a city to query:')
location = geolocator.geocode(lookup_city)

# return coordinates for input city
lat = location.latitude
lng = location.longitude
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=50000&location=%s,%s&key=%s" % (lat, lng, api_key)
print(url)
response = req.get(url).json()
restaurants = []
ratings = []
locations = []
lats = []
lngs = []
for x in range(len(response['results'])):
        try:
            restaurants.append(response['results'][x]['name'])
            ratings.append(response['results'][x]['rating'])
            locations.append(response['results'][x]['vicinity'])
            lats.append(response['results'][x]['geometry']['location']['lat'])
            lngs.append(response['results'][x]['geometry']['location']['lng'])
        except:
            ratings.append('No rating available.')
            locations.append('No address available')
            lats.append('No latitude available')
            lngs.append('No longitude available')
            
next_page_token = response['next_page_token']
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=10000&location=%s,%s&key=%s&pagetoken=%s" % (lat, lng, api_key, next_page_token)
print(url)
print()
response = req.get(url).json()
for x in range(len(response['results'])):
    try:
        restaurants.append(response['results'][x]['name'])
        ratings.append(response['results'][x]['rating'])
        locations.append(response['results'][x]['vicinity'])
        lats.append(response['results'][x]['geometry']['location']['lat'])
        lngs.append(response['results'][x]['geometry']['location']['lng'])
    except:
        ratings.append('No rating available.')
        locations.append('No address available')
        lats.append('No latitude available')
        lngs.append('No longitude available')

#time.sleep(60)

#next_page_token = response['next_page_token']
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=10000&location=%s,%s&key=%s&pagetoken=%s" % (lat, lng, api_key, next_page_token)
print(url)
response = req.get(url).json()
for x in range(len(response['results'])):
    try:
        restaurants.append(response['results'][x]['name'])
        ratings.append(response['results'][x]['rating'])
        locations.append(response['results'][x]['vicinity'])
        lats.append(response['results'][x]['geometry']['location']['lat'])
        lngs.append(response['results'][x]['geometry']['location']['lng'])
    except:
        ratings.append('No rating available.')
        locations.append('No address available')
        lats.append('No latitude available')
        lngs.append('No longitude available')
            
df = pd.DataFrame(columns={})
df["Restaurant"] = restaurants
df["Ratings"] = ratings
df["Address"] = locations
df["Latitude"] = lats
df["Longitude"] = lngs
print(len(df))
# Out:
# Enter a city to query:Austin, TX
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=50000&location=30.2711286,-97.7436995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=10000&location=30.2711286,-97.7436995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAOfbEHHRQzobn6BZ6KbnXaCOmq9wb6-ETpzhJx9GAfe6_RMLH9sXuF3fpldbgDkjMfPkamJADpVI8zI6egk05G9n-5TMltujvjk08fk4ZPbf0HeYktaNmY36eisWSaTxfZdsqCMoYSiWIPkZHGXlOwg5OBKZk_U3tEeAnu8WIBUs6IVsMFDqSTTgMaerl8-wrpAG70H0ukqoLBVpsloxr332LOhi1wVTY2QRiHR0DjE1tbFzW2GWeDTin4tpXE9t0TYMQ2AydU6qxxFHRF6lqe-Lpq8GPMctboLrwmheddopR7550UlPtynaoHglIeUmSoWKRZX7RDNG0CkHadNrY9WKMjAIdqf219Da_hAagdvlhk9U0RODd14VyxX0RnCSuBIQcMvr2hwBr3CLM-r4lrgc-RoUjETt_6eF_RblbjU2kpBrCfa7nqY
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=10000&location=30.2711286,-97.7436995&key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAOfbEHHRQzobn6BZ6KbnXaCOmq9wb6-ETpzhJx9GAfe6_RMLH9sXuF3fpldbgDkjMfPkamJADpVI8zI6egk05G9n-5TMltujvjk08fk4ZPbf0HeYktaNmY36eisWSaTxfZdsqCMoYSiWIPkZHGXlOwg5OBKZk_U3tEeAnu8WIBUs6IVsMFDqSTTgMaerl8-wrpAG70H0ukqoLBVpsloxr332LOhi1wVTY2QRiHR0DjE1tbFzW2GWeDTin4tpXE9t0TYMQ2AydU6qxxFHRF6lqe-Lpq8GPMctboLrwmheddopR7550UlPtynaoHglIeUmSoWKRZX7RDNG0CkHadNrY9WKMjAIdqf219Da_hAagdvlhk9U0RODd14VyxX0RnCSuBIQcMvr2hwBr3CLM-r4lrgc-RoUjETt_6eF_RblbjU2kpBrCfa7nqY
# 20

# %%
# rankby importance w/ 60 results

def rankby_importance_page_token():
    # prompt user for input city
    lookup_city = input('Enter a city to query:')
    location = geolocator.geocode(lookup_city)
    # return coordinates for input city
    lat = location.latitude
    lng = location.longitude
    for x in range(5):
        lat = lat - 1
        lng = lng - 1
        url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence&radius=50000&location=%s,%s&key=%s" \
        % (lat, lng, api_key)
        response = req.get(url).json()
        restaurants = []
        ratings = []
        locations = []
        lats = []
        lngs = []
        for x in range(len(response['results'])):
                try:
                    restaurants.append(response['results'][x]['name'])
                    ratings.append(response['results'][x]['rating'])
                    locations.append(response['results'][x]['vicinity'])
                    lats.append(response['results'][x]['geometry']['location']['lat'])
                    lngs.append(response['results'][x]['geometry']['location']['lng'])
                except:
                    ratings.append('No rating available.')
                    locations.append('No address available')
                    lats.append('No latitude available')
                    lngs.append('No longitude available')
        for x in range(2):
            try:
                next_page_token = response['next_page_token']
                url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=prominence\
                &radius=50000&location=%s,%s&key=%s&pagetoken=%s" % (lat, lng, api_key, next_page_token)
                response = req.get(url).json()
                for x in range(len(response['results'])):
                    try:
                        restaurants.append(response['results'][x]['name'])
                        ratings.append(response['results'][x]['rating'])
                        locations.append(response['results'][x]['vicinity'])
                        lats.append(response['results'][x]['geometry']['location']['lat'])
                        lngs.append(response['results'][x]['geometry']['location']['lng'])
                    except:
                        ratings.append('No rating available.')
                        locations.append('No address available')
                        lats.append('No latitude available')
                        lngs.append('No longitude available')
            except:
                pass
    df = pd.DataFrame(columns={})
    df["Restaurant"] = restaurants
    df["Ratings"] = ratings
    df["Address"] = locations
    df["Latitude"] = lats
    df["Longitude"] = lngs
    print(df)

# %%
rankby_importance_page_token()

# %%
# rankby distance

def rankby_distance():
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=restaurant&rankby=distance&location=%s,%s&key=%s" \
    % (lat, lng, api_key)
    print(url)
    response = req.get(url).json()
    restaurants = []
    ratings = []
    locations = []
    lats = []
    lngs = []
    next_page_token = response['next_page_token']
    for x in range(len(response['results'])):
        try:
            restaurants.append(response['results'][x]['name'])
            ratings.append(response['results'][x]['rating'])
            locations.append(response['results'][x]['vicinity'])
            lats.append(response['results'][x]['geometry']['location']['lat'])
            lngs.append(response['results'][x]['geometry']['location']['lng'])
        except:
            ratings.append('No rating available.')
            locations.append('No address available')
            lats.append('No latitude available')
            lngs.append('No longitude available')
    df = pd.DataFrame(columns={})
    df["Restaurant"] = restaurants
    df["Ratings"] = ratings
    df["Address"] = locations
    df["Latitude"] = lats
    df["Longitude"] = lngs
    print(len(df))

# %%
rankby_distance()
