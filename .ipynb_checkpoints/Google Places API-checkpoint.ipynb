# %%
import json
import time
import pandas as pd
import requests as req
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# %%
input_city = input('Enter a city to query:')
location = geolocator.geocode(input_city)
latitude = location.latitude
longitude = location.longitude
# Out:
# Enter a city to query:Austin

# %%
def google():
    #1
    target_city = {"lat": latitude, "lng": longitude}
    target_type = "restaurant"
    radius = 8000
    rankby = 'prominence'
    gkey = "AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY"
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&location=%s,%s&radius=%s&type=%s&rankby=%s" % (gkey, target_city["lat"],
                                                                                                            target_city["lng"], 
                                                                                                            radius, target_type, rankby)
    response = req.get(url).json()
    names3 = []
    addresses3 = []
    ratings3 = []

    for x in range(len(response['results'])):
        try:
            names3.append(response['results'][x]['name'])
            addresses3.append(response['results'][x]['vicinity'])
            ratings3.append(response['results'][x]['rating'])
        except:
            names3.append('N/A')
            addresses3.append('N/A')
            ratings3.append('N/A')
    time.sleep(3)        
    # 2
    page_token = response['next_page_token']
    url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&pagetoken=%s" % (gkey, page_token)
    response2 = req.get(url2).json()
    for x in range(len(response2['results'])):
        try:
            names3.append(response2['results'][x]['name'])
            addresses3.append(response2['results'][x]['vicinity'])
            ratings3.append(response2['results'][x]['rating'])
        except:
            names3.append('N/A')
            addresses3.append('N/A')
            ratings3.append('N/A')
    print(url2)
    page_token2 = response2['next_page_token']
    time.sleep(3)

    # 3
    url3 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&pagetoken=%s" % (gkey, page_token2)
    response3 = req.get(url3).json()
    for x in range(len(response2['results'])):
        try:
            names3.append(response3['results'][x]['name'])
            addresses3.append(response3['results'][x]['vicinity'])
            ratings3.append(response3['results'][x]['rating'])
        except:
            names3.append('N/A')
            addresses3.append('N/A')
            ratings3.append('N/A')

    df3 = pd.DataFrame(columns={})
    df3['Name'] = names3
    df3['Rating'] = ratings3
    df3['Address'] = addresses3
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAAClTys4er7uz5b601-ifAi2rJ7JIYQA5sLunrVrvkb1xqraOeijAmGldQyOs5ECazKRNkxrWkMXSUYAXng86Zip43s2QdstFheTYcXQg64KwEOEEbmK3Ifhzjqcfmn5Pcn7-uwVMrb24ziTaDXe04wYEcSWi0g8v0Vae8SDFyoTiwbJk6QDAwdpV2kyDNRqSRTVJ16Ha7wpbSF91BDh2RI4gpkQCqUty4Qs-NXVSz9rrvaiYxvhbgLDPq2dTFZQwkgQodE0gRDCmLXvxU5CEpnP7R49CSFHYCTIJgKuEYuekM1FHl3UVPNQ49LoRF0aXMD9SCUxyrCnhu_BSbbOHoBFvF2ZeDYYynBMptkaAtWYb1ItfR7K5Vxz26x7rHP96nxIQUP04GDjAP7Z7_zVXqHakvxoUeGSrRDWFyrFzLTaNLxXjPFs86gk
#                                                 Name  Rating  \
# 0               Sheraton Austin Hotel at the Capitol     4.0
# 1                       Holiday Inn Austin Town Lake     3.9
# 2            Embassy Suites by Hilton Austin Central     3.9
# 3                                           Parkside     4.2
# 4                                       P.F. Chang's     4.0
# ...

# %%
# # 2
# page_token = response['next_page_token']
# url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&pagetoken=%s" % (gkey, page_token)
# response2 = req.get(url2).json()
# for x in range(len(response2['results'])):
#     try:
#         names3.append(response2['results'][x]['name'])
#         addresses3.append(response2['results'][x]['vicinity'])
#         ratings3.append(response2['results'][x]['rating'])
#     except:
#         names3.append('N/A')
#         addresses3.append('N/A')
#         ratings3.append('N/A')
# print(url2)
# print(response2['next_page_token'])
# page_token2 = response2['next_page_token']
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyAz4kL-cuqujVaQ_nozJhFc_kGPszQgAVY&pagetoken=CqQCHQEAANHDcUPkIIqSfAGcBf-NQdyHmystW8WAPmaH7YFrrUyrxLPnEaIYDjpgG16IjdQ1t26yImZbRLCI9yL7jwshcZ74zl6soJkJu_hYFPe8OoykQzqMKImiDm8O0sc6WFWYO6FfgrqYHjAGQ-8jjM9cfucrZ2PFJkXm_2BoCB6nLmy7J3JYpnveHc-oiUFuBARnLXw9y-VkDh-iYHMWLSgeI1lIMKS6mF0nyvu6JS21BvAqd__KUHqq41yWr3e6XqqS-16l7aPUFoajmglSVu2fi4ieLk4l6YPnu5Q9wti3OmahtQKlbeBJVPCNY1xzDcfXvjDZyY2VNzoiGG8uhiaAyGTk2Ijz_bwVj9aWNT94B36cGSCSCKdDwORZbWo8o_6KqxIQXXw97AaYATb_TRdnb6QKyBoUyyg00U5cpx95tFYM60sZn4P2MFQ
# ...

# %%
# 3
url3 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=%s&pagetoken=%s" % (gkey, page_token2)
response3 = req.get(url3).json()
for x in range(len(response2['results'])):
    try:
        names3.append(response3['results'][x]['name'])
        addresses3.append(response3['results'][x]['vicinity'])
        ratings3.append(response3['results'][x]['rating'])
    except:
        names3.append('N/A')
        addresses3.append('N/A')
        ratings3.append('N/A')

# %%
df3 = pd.DataFrame(columns={})
df3['Name'] = names3
df3['Rating'] = ratings3
df3['Address'] = addresses3
df3.head(60)
